# %% [markdown]
# # TD 1: K-means clustering
#
#
# ## Part 2:  K-means clustering using Python and Scikit learn

# %% [markdown]
# In order to complete this part of the practical, please be sure to use Google Colab.
# To complete the code, you may use `help_kmeans.ipynb`  for help.
#
# You will use the K-means algorithm to cluster patients into two groups: chronic kidney disease and no chronic kidney disease.
# The dataset can be downloaded from: https://drive.google.com/file/d/1ILQrHZJCVs-ggkCDGSC54enm3EVjPKj4/view?usp=sharing.
#
# ___
# It is **important to note that we will NOT use the labels for the K-means clustering algorithm, since it is an unsupervised learning algorithm.**
#
# In this study we will use the labels to evaluate the k-means clustering results.
# ___
#
# ## The Data
#
# We will use a data frame with 400 instances on the following 24 variables.
# 11 of the variables are numeric, and the remaining 13 are nominal.
#
# 1. Age(numerical): *age* in years
#
# 2. Blood Pressure(numerical): *bp* in mm/Hg
#
# 3. Specific Gravity(numerical): *sg* - (1.005,1.010,1.015,1.020,1.025)
#
# 4. Albumin(numerical): *al* - (0,1,2,3,4,5)
#
# 5. Sugar(numerical): *su* - (0,1,2,3,4,5)
#
# 6. Red Blood Cells(nominal): *rbc* - (normal,abnormal)
#
# 7. Pus Cell (nominal): *pc* - (normal,abnormal)
#
# 8. Pus Cell clumps(nominal): *pcc* - (present,notpresent)
#
# 9. Bacteria(nominal): *ba* - (present,notpresent)
#
# 10. Blood Glucose Random(numerical): *bgr* in mgs/dl
#
# 11. Blood Urea(numerical): *bu* in mgs/dl
#
# 12. Serum Creatinine(numerical): *sc* in mgs/dl
#
# 13. Sodium(numerical): *sod* in mEq/L
#
# 14. Potassium(numerical): *pot* in mEq/L
#
# 15. Hemoglobin(numerical): *hemo* in gms
#
# 16. Packed Cell Volume(numerical): *pcv*
#
# 17. White Blood Cell Count(numerical): *wc* in cells/cumm
#
# 18. Red Blood Cell Count(numerical): *rbc* in millions/cmm
#
# 19. Hypertension(nominal): *htn* - (yes,no)
#
# 20. Diabetes Mellitus(nominal): *dm* - (yes,no)
#
# 21. Coronary Artery Disease(nominal): *cad* - (yes,no)
#
# 22. Appetite(nominal): *appet* - (good,poor)
#
# 23. Pedal Edema(nominal): *pe* - (yes,no)
# 24. Anemia(nominal): *ane* - (yes,no)

# %% [markdown]
# ### Link Google Colab notebook to drive folder.
#
# In order to read the data file from your drive, make sure you are in the correct directory. You can change the path using the os.chdir command.

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
os.chdir('drive/MyDrive/Colab') # main folder of Google Drive account
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-aab945f03ed0> in <cell line: 3>()
#       1 import os
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive', force_remount = True)
#       4 os.chdir('drive/MyDrive/Colab') # main folder of Google Drive account
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# ...

# %% [markdown]
# ### Import Libraries
#
# **Import the libraries you usually use for data analysis.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Get the Data
#
# **Read in the "chronic_kidney_disease" file using read_csv.**

# %% [markdown]
# **Check the head of the data**

# %% [markdown]
# **Check the info() and describe() methods on the data**

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %% [markdown]
# ### Data Preparation

# %%
# Separate the labels from the variables

# %%
# Step 1: separate the numerical and nominal attributes (you should get two diffrent datasets)
# The nominal attributes are: "rbc","pc","pcc","ba","htn","dm", "cad", "appet", "pe", "ane"

# %%
# Step 2: Replace missing values of numerical dataset with a median (or means, zeros, etc.)

# Step 2.a: fit the imputer instance to the data

# Step 2.b: Transform the dataset by replacing the missing values

# %% [markdown]
# **Use the info function to make sure the imputer function worked**

# %% [markdown]
# **Handling nominal attributes**

# %%
# Step 1: Use the pandas function factorize() to transform the nominal dataset

# %%
# Step 2: Replace missing nominal values by the most frequent ones

# Step 2.a: fit the imputer instance to the data

# Step 2.b: transform the dataset by replacing the missing values by the most frequent values

# %% [markdown]
# **Merge the numerical and categorical datasets to get the complete preprocessed dataset in a single dataframe.**

# %% [markdown]
# ### Save final preprocessed dataset

# %% [markdown]
# ### K-means model

# %% [markdown]
# **Create an instance of a K means model with two clusters**

# %% [markdown]
# **Fit the model to all data except for the class label**

# %% [markdown]
# **What are the cluster center vectors?**

# %% [markdown]
# **What is the assigned cluster for each patient?**

# %% [markdown]
# ### Result interpretation
#
# There is no perfect way to evaluate clustering if you don't have the labels. In this practical session, we will take advantage of the availibility of labels to evaluate our clusters. In the next session, we will look into other methods.

# %% [markdown]
# **Create a new column for our data called 'cluster_model' which is a binary class column.**

# %% [markdown]
# **Create a confusion matrix and classification report to see how well the K-means clustering algorithm worked without being given any labels.**
